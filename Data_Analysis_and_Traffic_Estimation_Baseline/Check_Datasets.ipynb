# %%
#! pip install pyarrow

# %% [markdown]
# ### Check the NYC dataset
#
# Can be obtained from https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page?spm=5aebb161.2ef5001f.0.0.14b05171AFZ96Z&file=tlc-trip-record-data.page

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_parquet('yellow_tripdata_2024-01.parquet')
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1               1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2               1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3               1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4               1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ...           ...                  ...                   ...              ...
# 2964619         2  2024-01-31 23:45:59   2024-01-31 23:54:36              NaN
# 2964620         1  2024-01-31 23:13:07   2024-01-31 23:27:52              NaN
# 2964621         2  2024-01-31 23:19:00   2024-01-31 23:38:00              NaN
# 2964622         2  2024-01-31 23:07:23   2024-01-31 23:25:14              NaN
# 2964623         1  2024-01-31 23:58:25   2024-02-01 00:13:30              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 1.72         1.0                  N           186
# 1                 1.80         1.0                  N           140
# 2                 4.70         1.0                  N           236
# 3                 1.40         1.0                  N            79
# 4                 0.80         1.0                  N           211
# ...                ...         ...                ...           ...
# 2964619           3.18         NaN               None           107
# 2964620           4.00         NaN               None           114
# 2964621           3.33         NaN               None           211
# 2964622           3.06         NaN               None           107
# 2964623           8.10         NaN               None           138
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                  79             2        17.70   1.00      0.5        0.00
# 1                 236             1        10.00   3.50      0.5        3.75
# 2                  79             1        23.30   3.50      0.5        3.00
# 3                 211             1        10.00   3.50      0.5        2.00
# 4                 148             1         7.90   3.50      0.5        3.20
# ...               ...           ...          ...    ...      ...         ...
# 2964619           263             0        15.77   0.00      0.5        2.00
# 2964620           236             0        18.40   1.00      0.5        2.34
# 2964621            25             0        19.97   0.00      0.5        0.00
# 2964622            13             0        23.88   0.00      0.5        5.58
# 2964623            75             0        32.40   7.75      0.5        7.29
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    1.0         22.70
# 1                0.00                    1.0         18.75
# 2                0.00                    1.0         31.30
# 3                0.00                    1.0         17.00
# 4                0.00                    1.0         16.10
# ...               ...                    ...           ...
# 2964619          0.00                    1.0         21.77
# 2964620          0.00                    1.0         25.74
# 2964621          0.00                    1.0         23.97
# 2964622          0.00                    1.0         33.46
# 2964623          6.94                    1.0         55.88
#
#          congestion_surcharge  Airport_fee
# 0                         2.5          0.0
# 1                         2.5          0.0
# 2                         2.5          0.0
# 3                         2.5          0.0
# 4                         2.5          0.0
# ...                       ...          ...
# 2964619                   NaN          NaN
# 2964620                   NaN          NaN
# 2964621                   NaN          NaN
# 2964622                   NaN          NaN
# 2964623                   NaN          NaN
#
# [2964624 rows x 19 columns]

# %%
zones = pd.read_csv('taxi_zone_lookup.csv')
zones
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                      NaN          NaN
# 264         265            NaN           Outside of NYC          NaN
#
# [265 rows x 4 columns]

# %% [markdown]
# #### Not the best dataset for several reasons:
#
# + The dataset does not contain the precise location of the pickup and dropoff points. Instead, it uses the taxi zone ID, which is not very precise. Ideally, we need the latitude and longitude coordinates of the pickup and dropoff points to accurately analyze the data.
#
# + The dataset contains information only about the pickup and dropoff, which is insufficient to analyze the entire trip. Ideally, we need to know the checkpoints (at least) to build the root and analyze the traffic

# %% [markdown]
# ### Check the California vehicle information dataset
#
# Available at https://data.transportation.gov/Automobiles/Next-Generation-Simulation-NGSIM-Vehicle-Trajector/8ect-6jqj/about_data
#
# **Btw, there are some video file datasets**
#
# Check it: https://data.transportation.gov/Automobiles/Next-Generation-Simulation-NGSIM-Program-I-80-Vide/2577-gpny
#
# **Column description:**
#
# Vehicle_ID Vehicle identification number (ascending by time of entry into section). REPEATS ARE NOT ASSOCIATED.
#
# Frame_ID Frame Identification number (ascending by start time)
#
# Total_Frames Total number of frames in which the vehicle appears in this data set
#
# Global_Time Elapsed time in milliseconds since Jan 1, 1970.
#
# Local_X Lateral (X) coordinate of the front center of the vehicle in feet with respect to the left-most edge of the section in the direction of travel.
#
# Local_Y Longitudinal (Y) coordinate of the front center of the vehicle in feet with respect to the entry edge of the section in the direction of travel.
#
# Global_X X Coordinate of the front center of the vehicle in feet based on CA State Plane III in NAD83. Attribute Domain Val
#
# Global_Y Y Coordinate of the front center of the vehicle in feet based on CA State Plane III in NAD83.
#
# v_length Length of vehicle in feet
#
# v_Width Width of vehicle in feet
#
# v_Class Vehicle type: 1 - motorcycle, 2 - auto, 3 - truck
#
# v_Vel Instantaneous velocity of vehicle in feet/second.
#
# v_Acc Instantaneous acceleration of vehicle in feet/second square.
#
# Lane_ID Current lane position of vehicle. Lane 1 is farthest left lane; lane 5 is farthest right lane. Lane 6 is the auxiliary lane between Ventura Boulevard on-ramp and the Cahuenga Boulevard off-ramp. Lane 7 is the on-ramp at Ventura Boulevard, and Lane 8 is the off-ramp at Cahuenga Boulevard.
#
# O_Zone Origin zones of the vehicles, i.e., the place where the vehicles enter the tracking system. There are 11 origins in the study area, numbered from 101 through 111. Please refer to the data analysis report for more detailed information.

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Next_Generation_Simulation__NGSIM__Vehicle_Trajectories_and_Supporting_Data_20250301.csv', 
                      nrows=1000000)

# %%
df.head()
# Out:
#    Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X   Local_Y  \
# 0         515      2330          1123  1118848075000   30.034   188.062
# 1         515      2330          1123  1118848075000   30.034   188.062
# 2        2224      6548          1902  1113437421700   41.429   472.901
# 3        2127      6459           567  1118847624800   19.632  1775.614
# 4        1033      4827           592  1118848324700    6.202  1701.144
#
#       Global_X     Global_Y  v_length  v_Width  v_Class  v_Vel  v_Acc  \
# 0  6451203.729  1873252.549      13.0      6.9        2  23.31   2.05
# 1  6451203.729  1873252.549      13.0      6.9        2  23.31   2.05
# 2  6042814.264  2133542.012      14.3      6.9        2  26.54  -0.76
# 3  6452425.122  1872172.475      13.5      6.9        2  37.52  11.20
# 4  6452347.673  1872258.452      13.5      4.4        2  41.99   0.10
#
#    Lane_ID  O_Zone  D_Zone  Int_ID  Section_ID  Direction  Movement  \
# 0        3     NaN     NaN     NaN         NaN        NaN       NaN
# 1        3     NaN     NaN     NaN         NaN        NaN       NaN
# 2        4     NaN     NaN     NaN         NaN        NaN       NaN
# 3        2     NaN     NaN     NaN         NaN        NaN       NaN
# 4        1     NaN     NaN     NaN         NaN        NaN       NaN
#
#    Preceding  Following  Space_Headway  Time_Headway Location
# 0        500        523         119.10          5.11   us-101
# 1        500        523         119.10          5.11   us-101
# 2       2208       2211          53.34          2.01     i-80
# 3       2124       2132          48.92          1.30   us-101
# 4       1029       1040          38.81          0.92   us-101

# %%
df.Location.value_counts()
# Out:
# us-101        538247
# i-80          202301
# lankershim    168228
# peachtree      91224
# Name: Location, dtype: int64

# %% [markdown]
# **REPRESENT TIME NORMALLY**

# %%
df['datetime_LA'] = pd.to_datetime(df['Global_Time'], unit='ms')
df['datetime_LA'] = df['datetime_LA'].dt.tz_localize('UTC')
df['datetime_LA'] = df['datetime_LA'].dt.tz_convert('America/Los_Angeles')
df['Global_Time_seconds'] = df['Global_Time'] / 1000
df = df.drop(columns=['Global_Time'])
df.head()
# Out:
#    Vehicle_ID  Frame_ID  Total_Frames  Local_X   Local_Y     Global_X  \
# 0         515      2330          1123   30.034   188.062  6451203.729
# 1         515      2330          1123   30.034   188.062  6451203.729
# 2        2224      6548          1902   41.429   472.901  6042814.264
# 3        2127      6459           567   19.632  1775.614  6452425.122
# 4        1033      4827           592    6.202  1701.144  6452347.673
#
#       Global_Y  v_length  v_Width  v_Class  v_Vel  v_Acc  Lane_ID  O_Zone  \
# 0  1873252.549      13.0      6.9        2  23.31   2.05        3     NaN
# 1  1873252.549      13.0      6.9        2  23.31   2.05        3     NaN
# 2  2133542.012      14.3      6.9        2  26.54  -0.76        4     NaN
# 3  1872172.475      13.5      6.9        2  37.52  11.20        2     NaN
# 4  1872258.452      13.5      4.4        2  41.99   0.10        1     NaN
#
#    D_Zone  Int_ID  Section_ID  Direction  Movement  Preceding  Following  \
# 0     NaN     NaN         NaN        NaN       NaN        500        523
# 1     NaN     NaN         NaN        NaN       NaN        500        523
# 2     NaN     NaN         NaN        NaN       NaN       2208       2211
# 3     NaN     NaN         NaN        NaN       NaN       2124       2132
# 4     NaN     NaN         NaN        NaN       NaN       1029       1040
#
#    Space_Headway  Time_Headway Location                      datetime_LA  \
# 0         119.10          5.11   us-101        2005-06-15 08:07:55-07:00
# 1         119.10          5.11   us-101        2005-06-15 08:07:55-07:00
# 2          53.34          2.01     i-80 2005-04-13 17:10:21.700000-07:00
# 3          48.92          1.30   us-101 2005-06-15 08:00:24.800000-07:00
# 4          38.81          0.92   us-101 2005-06-15 08:12:04.700000-07:00
#
#    Global_Time_seconds
# 0         1.118848e+09
# 1         1.118848e+09
# 2         1.113437e+09
# 3         1.118848e+09
# 4         1.118848e+09

# %% [markdown]
# ### The coordinate system looks pretty weird. I guess the only way to move one is to try to convert it to lat and lon.

# %% [markdown]
# ### Try to convert it
#
# Use two methods to see if they lead to the same answer
#
# Refefences:
#
# https://epsg.io/2227
#
# https://epsg.io/6420

# %%
df1 = df.copy()
df1 = df1[['Global_X', 'Global_Y', 'Location']]
df1.columns = ['easting', 'northing', 'Location']
df1
# Out:
#             easting     northing   Location
# 0       6451203.729  1873252.549     us-101
# 1       6451203.729  1873252.549     us-101
# 2       6042814.264  2133542.012       i-80
# 3       6452425.122  1872172.475     us-101
# 4       6452347.673  1872258.452     us-101
# ...             ...          ...        ...
# 999995  6452256.994  1872291.450     us-101
# 999996  2230843.984  1377146.651  peachtree
# 999997  6452024.672  1872479.969     us-101
# 999998  6042794.502  2133702.375       i-80
# 999999  6042613.993  2134650.719       i-80
#
# [1000000 rows x 3 columns]

# %%
# Grok
import pyproj

def convert_to_latlon(df):
    source_crs = pyproj.CRS("EPSG:6420")
    target_crs = pyproj.CRS("EPSG:4326")
    transformer = pyproj.Transformer.from_crs(source_crs, target_crs, always_xy=True)
    
    lon, lat = transformer.transform(df['easting'], df['northing'])
    df['longitude_grok'] = lon
    df['latitude_grok'] = lat
    return df

# %%
# DeepSeek
from pyproj import Transformer

def converter(df):
    transformer = Transformer.from_crs("EPSG:2227", "EPSG:4326")

    # Convert coordinates using the transformer
    df['latitude_deepseek'], df['longitude_deepseek'] = transformer.transform(
        df['easting'].values,
        df['northing'].values
    )
    
    return df

# %%
df1 = convert_to_latlon(df1)
df1 = converter(df1)
df1 = df1[['Location', 'longitude_grok', 'latitude_grok', 'longitude_deepseek', 'latitude_deepseek', 'easting', 'northing']]
df1
# Out:
#          Location  longitude_grok  latitude_grok  longitude_deepseek  \
# 0          us-101     -120.878952      37.138848         -120.878952
# 1          us-101     -120.878952      37.138848         -120.878952
# 2            i-80     -122.296902      37.840647         -122.296902
# 3          us-101     -120.874747      37.135895         -120.874747
# 4          us-101     -120.875014      37.136131         -120.875014
# ...           ...             ...            ...                 ...
# 999995     us-101     -120.875326      37.136220         -120.875326
# 999996  peachtree     -134.975401      34.855817         -134.975401
# 999997     us-101     -120.876125      37.136736         -120.876125
# 999998       i-80     -122.296981      37.841087         -122.296981
# 999999       i-80     -122.297669      37.843681         -122.297669
#
#         latitude_deepseek      easting     northing
# 0               37.138848  6451203.729  1873252.549
# 1               37.138848  6451203.729  1873252.549
# 2               37.840647  6042814.264  2133542.012
# 3               37.135895  6452425.122  1872172.475
# 4               37.136131  6452347.673  1872258.452
# ...                   ...          ...          ...
# 999995          37.136220  6452256.994  1872291.450
# 999996          34.855817  2230843.984  1377146.651
# 999997          37.136736  6452024.672  1872479.969
# 999998          37.841087  6042794.502  2133702.375
# 999999          37.843681  6042613.993  2134650.719
#
# [1000000 rows x 7 columns]

# %% [markdown]
# **Two ways which were assumed to be correct match exactly, therefore, might be correct**

# %%
df2 = df1.loc[df1['Location'] == 'us-101']
df2 = df2.iloc[:10, 0:]
df2
# Out:
#    Location  longitude_grok  latitude_grok  longitude_deepseek  \
# 0    us-101     -120.878952      37.138848         -120.878952
# 1    us-101     -120.878952      37.138848         -120.878952
# 3    us-101     -120.874747      37.135895         -120.874747
# 4    us-101     -120.875014      37.136131         -120.875014
# 5    us-101     -120.875014      37.136131         -120.875014
# 6    us-101     -120.877397      37.137612         -120.877397
# 7    us-101     -120.878199      37.138270         -120.878199
# 8    us-101     -120.878199      37.138270         -120.878199
# 15   us-101     -120.875233      37.136115         -120.875233
# 16   us-101     -120.875233      37.136115         -120.875233
#
#     latitude_deepseek      easting     northing
# 0           37.138848  6451203.729  1873252.549
# 1           37.138848  6451203.729  1873252.549
# 3           37.135895  6452425.122  1872172.475
# 4           37.136131  6452347.673  1872258.452
# 5           37.136131  6452347.673  1872258.452
# 6           37.137612  6451655.238  1872800.663
# 7           37.138270  6451422.353  1873041.018
# 8           37.138270  6451422.353  1873041.018
# 15          37.136115  6452284.002  1872253.037
# 16          37.136115  6452284.002  1872253.037

# %% [markdown]
# ### Visualize the data to see if it is accurate

# %%
import folium
center_lat = df2['latitude_grok'].mean()
center_lng = df2['longitude_grok'].mean()
center = [center_lat, center_lng]

m = folium.Map(location=center, zoom_start=5, tiles="Cartodb Positron")
for index, row in df2.iterrows():
    folium.Marker(location=[row['latitude_grok'], row['longitude_grok']]).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be917175025de05f8f32d41ac37ce467 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be917175025de05f8f32d41ac37ce467&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be917175025de05f8f32d41ac37ce467 = L.map(
#                 &quot;map_be917175025de05f8f32d41ac37ce467&quot;,
#                 {
#                     center: [37.13722351667654, -120.87669410435842],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ca619969202253df88ed0ea416ee3d15 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ca619969202253df88ed0ea416ee3d15.addTo(map_be917175025de05f8f32d41ac37ce467);
#
#
#             var marker_048bc9acf92f53a1c513539308dd4601 = L.marker(
#                 [37.13884826723999, -120.87895223473618],
#                 {
# }
#             ).addTo(map_be917175025de05f8f32d41ac37ce467);
#
#
#             var marker_08742abdb03dc1b5b8906c5741294749 = L.marker(
#                 [37.13884826723999, -120.87895223473618],
#                 {
# }
#             ).addTo(map_be917175025de05f8f32d41ac37ce467);
#
#
#             var marker_e600bd0b5d2e5f2597b3d03d22f7d50a = L.marker(
#                 [37.135895398824005, -120.87474735301771],
#                 {
# }
#             ).addTo(map_be917175025de05f8f32d41ac37ce467);
#
#
#             var marker_86d793e27480e4cb9525126e456d5f90 = L.marker(
#                 [37.136130678870245, -120.8750142167562],
#                 {
# }
#             ).addTo(map_be917175025de05f8f32d41ac37ce467);
#
#
#             var marker_8a5cc94904f70fdee74cfb6d3e25e438 = L.marker(
#                 [37.136130678870245, -120.8750142167562],
#                 {
# }
#             ).addTo(map_be917175025de05f8f32d41ac37ce467);
#
#
#             var marker_1d9973b7ecf3a65b219a13d9724471ff = L.marker(
#                 [37.13761219300427, -120.87739706110733],
#                 {
# }
#             ).addTo(map_be917175025de05f8f32d41ac37ce467);
#
#
#             var marker_5a29fc41c80ee0d66a9b18db44b63afa = L.marker(
#                 [37.13826973549747, -120.87819930261074],
#                 {
# }
#             ).addTo(map_be917175025de05f8f32d41ac37ce467);
#
#
#             var marker_f3af44c690879c445edac9c97b25d895 = L.marker(
#                 [37.13826973549747, -120.87819930261074],
#                 {
# }
#             ).addTo(map_be917175025de05f8f32d41ac37ce467);
#
#
#             var marker_4bf4de756fee8cb4dd6052ebe6bfa7ee = L.marker(
#                 [37.13611510586089, -120.87523256062639],
#                 {
# }
#             ).addTo(map_be917175025de05f8f32d41ac37ce467);
#
#
#             var marker_e828e07d77dd94a005ef47de2045a4dd = L.marker(
#                 [37.13611510586089, -120.87523256062639],
#                 {
# }
#             ).addTo(map_be917175025de05f8f32d41ac37ce467);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **!! THE PROBLEM: these points are not on the road, they are in the field!!**

# %% [markdown]
# ### Hypothesis
#
# Conversion types in different locations (we have four) can be different. Hence, try to ask AI (unfortunately, could not find any relevant and suitable information anywhere else) to give the appropriate transformations

# %%
df = pd.read_csv('Next_Generation_Simulation__NGSIM__Vehicle_Trajectories_and_Supporting_Data_20250301.csv', 
                      nrows=1000000)

# %%
df['datetime_LA'] = pd.to_datetime(df['Global_Time'], unit='ms')
df['datetime_LA'] = df['datetime_LA'].dt.tz_localize('UTC')
df['datetime_LA'] = df['datetime_LA'].dt.tz_convert('America/Los_Angeles')
df['Global_Time_seconds'] = df['Global_Time'] / 1000
df = df.drop(columns=['Global_Time'])
df.head()
# Out:
#    Vehicle_ID  Frame_ID  Total_Frames  Local_X   Local_Y     Global_X  \
# 0         515      2330          1123   30.034   188.062  6451203.729
# 1         515      2330          1123   30.034   188.062  6451203.729
# 2        2224      6548          1902   41.429   472.901  6042814.264
# 3        2127      6459           567   19.632  1775.614  6452425.122
# 4        1033      4827           592    6.202  1701.144  6452347.673
#
#       Global_Y  v_length  v_Width  v_Class  v_Vel  v_Acc  Lane_ID  O_Zone  \
# 0  1873252.549      13.0      6.9        2  23.31   2.05        3     NaN
# 1  1873252.549      13.0      6.9        2  23.31   2.05        3     NaN
# 2  2133542.012      14.3      6.9        2  26.54  -0.76        4     NaN
# 3  1872172.475      13.5      6.9        2  37.52  11.20        2     NaN
# 4  1872258.452      13.5      4.4        2  41.99   0.10        1     NaN
#
#    D_Zone  Int_ID  Section_ID  Direction  Movement  Preceding  Following  \
# 0     NaN     NaN         NaN        NaN       NaN        500        523
# 1     NaN     NaN         NaN        NaN       NaN        500        523
# 2     NaN     NaN         NaN        NaN       NaN       2208       2211
# 3     NaN     NaN         NaN        NaN       NaN       2124       2132
# 4     NaN     NaN         NaN        NaN       NaN       1029       1040
#
#    Space_Headway  Time_Headway Location                      datetime_LA  \
# 0         119.10          5.11   us-101        2005-06-15 08:07:55-07:00
# 1         119.10          5.11   us-101        2005-06-15 08:07:55-07:00
# 2          53.34          2.01     i-80 2005-04-13 17:10:21.700000-07:00
# 3          48.92          1.30   us-101 2005-06-15 08:00:24.800000-07:00
# 4          38.81          0.92   us-101 2005-06-15 08:12:04.700000-07:00
#
#    Global_Time_seconds
# 0         1.118848e+09
# 1         1.118848e+09
# 2         1.113437e+09
# 3         1.118848e+09
# 4         1.118848e+09

# %%
df1 = df.copy()
df1 = df1[['Global_X', 'Global_Y', 'Location']]
df1.columns = ['easting', 'northing', 'Location']
df1
# Out:
#             easting     northing   Location
# 0       6451203.729  1873252.549     us-101
# 1       6451203.729  1873252.549     us-101
# 2       6042814.264  2133542.012       i-80
# 3       6452425.122  1872172.475     us-101
# 4       6452347.673  1872258.452     us-101
# ...             ...          ...        ...
# 999995  6452256.994  1872291.450     us-101
# 999996  2230843.984  1377146.651  peachtree
# 999997  6452024.672  1872479.969     us-101
# 999998  6042794.502  2133702.375       i-80
# 999999  6042613.993  2134650.719       i-80
#
# [1000000 rows x 3 columns]

# %%
import pyproj

def convert_to_latlon(df):
    location = df['Location'].unique()[0]  # Ensure all rows have the same location
    crs_map = {
        'us-101': 'EPSG:2229',
        'lankershim': 'EPSG:2229',
        'i-80': 'EPSG:2227',
        'peachtree': 'EPSG:2264'
    }
    source_crs = pyproj.CRS(crs_map[location])
    target_crs = pyproj.CRS("EPSG:4326")
    transformer = pyproj.Transformer.from_crs(source_crs, target_crs, always_xy=True)
    lon, lat = transformer.transform(df['easting'], df['northing'])
    df['longitude_grok'] = lon
    df['latitude_grok'] = lat
    return df

# %%
df1 = convert_to_latlon(df1)
df1 = df1[['Location', 'longitude_grok', 'latitude_grok', 'easting', 'northing']]
df1
# Out:
#          Location  longitude_grok  latitude_grok      easting     northing
# 0          us-101     -118.365050      34.139234  6451203.729  1873252.549
# 1          us-101     -118.365050      34.139234  6451203.729  1873252.549
# 2            i-80     -119.729304      34.842749  6042814.264  2133542.012
# 3          us-101     -118.361001      34.136278  6452425.122  1872172.475
# 4          us-101     -118.361258      34.136513  6452347.673  1872258.452
# ...           ...             ...            ...          ...          ...
# 999995     us-101     -118.361558      34.136603  6452256.994  1872291.450
# 999996  peachtree     -131.991497      31.947541  2230843.984  1377146.651
# 999997     us-101     -118.362328      34.137119  6452024.672  1872479.969
# 999998       i-80     -119.729379      34.843189  6042794.502  2133702.375
# 999999       i-80     -119.730035      34.845786  6042613.993  2134650.719
#
# [1000000 rows x 5 columns]

# %%
df2 = df1.loc[df1['Location'] == 'us-101']
df2 = df2.iloc[:10, 0:]
df2
# Out:
#    Location  longitude_grok  latitude_grok      easting     northing
# 0    us-101     -118.365050      34.139234  6451203.729  1873252.549
# 1    us-101     -118.365050      34.139234  6451203.729  1873252.549
# 3    us-101     -118.361001      34.136278  6452425.122  1872172.475
# 4    us-101     -118.361258      34.136513  6452347.673  1872258.452
# 5    us-101     -118.361258      34.136513  6452347.673  1872258.452
# 6    us-101     -118.363553      34.137996  6451655.238  1872800.663
# 7    us-101     -118.364325      34.138655  6451422.353  1873041.018
# 8    us-101     -118.364325      34.138655  6451422.353  1873041.018
# 15   us-101     -118.361468      34.136498  6452284.002  1872253.037
# 16   us-101     -118.361468      34.136498  6452284.002  1872253.037

# %% [markdown]
# ### US-101

# %%
center_lat = df2['latitude_grok'].mean()
center_lng = df2['longitude_grok'].mean()
center = [center_lat, center_lng]

m = folium.Map(location=center, control_scale=True, tiles="Cartodb Positron")
for index, row in df2.iterrows():
    folium.Marker(location=[row['latitude_grok'], row['longitude_grok']]).add_to(m)
#m.save('map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57dd984e1ab35750c9fe44cc2b9ca7e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57dd984e1ab35750c9fe44cc2b9ca7e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57dd984e1ab35750c9fe44cc2b9ca7e4 = L.map(
#                 &quot;map_57dd984e1ab35750c9fe44cc2b9ca7e4&quot;,
#                 {
#                     center: [34.137607355159766, -118.3628757195576],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_57dd984e1ab35750c9fe44cc2b9ca7e4);
#
#
#
#
#
#             var tile_layer_7d6bc4e82f2ed3b523461e1831099beb = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7d6bc4e82f2ed3b523461e1831099beb.addTo(map_57dd984e1ab35750c9fe44cc2b9ca7e4);
#
#
#             var marker_7a886e692382d278be279ce620f5335d = L.marker(
#                 [34.13923367949842, -118.365050201637],
#                 {
# }
#             ).addTo(map_57dd984e1ab35750c9fe44cc2b9ca7e4);
#
#
#             var marker_9ba9f31ee0d90d33c9c91c799df4e312 = L.marker(
#                 [34.13923367949842, -118.365050201637],
#                 {
# }
#             ).addTo(map_57dd984e1ab35750c9fe44cc2b9ca7e4);
#
#
#             var marker_dca83e1d26174870175134117df32b09 = L.marker(
#                 [34.13627791851052, -118.36100104317349],
#                 {
# }
#             ).addTo(map_57dd984e1ab35750c9fe44cc2b9ca7e4);
#
#
#             var marker_22162cf7198acd19adb5a53eb0a7ba51 = L.marker(
#                 [34.13651340589235, -118.36125800107918],
#                 {
# }
#             ).addTo(map_57dd984e1ab35750c9fe44cc2b9ca7e4);
#
#
#             var marker_a02470f0e4389549b50d59c761336174 = L.marker(
#                 [34.13651340589235, -118.36125800107918],
#                 {
# }
#             ).addTo(map_57dd984e1ab35750c9fe44cc2b9ca7e4);
#
#
#             var marker_f1af3c4116d278cadd19e939c0f356c8 = L.marker(
#                 [34.13799646078633, -118.36355269805406],
#                 {
# }
#             ).addTo(map_57dd984e1ab35750c9fe44cc2b9ca7e4);
#
#
#             var marker_e085892e14f60508ff60a727a6e55bfc = L.marker(
#                 [34.138654603467536, -118.36432518092684],
#                 {
# }
#             ).addTo(map_57dd984e1ab35750c9fe44cc2b9ca7e4);
#
#
#             var marker_868d9e44c904d42b78bc004c2a901afa = L.marker(
#                 [34.138654603467536, -118.36432518092684],
#                 {
# }
#             ).addTo(map_57dd984e1ab35750c9fe44cc2b9ca7e4);
#
#
#             var marker_9fc8d552ad8f1ca571b046b25f669da6 = L.marker(
#                 [34.136497897292095, -118.3614683435311],
#                 {
# }
#             ).addTo(map_57dd984e1ab35750c9fe44cc2b9ca7e4);
#
#
#             var marker_5f9529b6ebbd71e69343f6dcf102a588 = L.marker(
#                 [34.136497897292095, -118.3614683435311],
#                 {
# }
#             ).addTo(map_57dd984e1ab35750c9fe44cc2b9ca7e4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **This is fine, but let's check others**

# %% [markdown]
# ### I-80

# %%
df2 = df1.loc[df1['Location'] == 'i-80']
df2 = df2.iloc[:10, 0:]

# %%
# not sure if it makes sense, no idea where that is
center_lat = df2['latitude_grok'].mean()
center_lng = df2['longitude_grok'].mean()
center = [center_lat, center_lng]

m = folium.Map(location=center, control_scale=True, tiles="Cartodb Positron")
for index, row in df2.iterrows():
    folium.Marker(location=[row['latitude_grok'], row['longitude_grok']]).add_to(m)
#m.save('map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_75c4b15af0a7cc4d13155201e3e09e5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_75c4b15af0a7cc4d13155201e3e09e5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_75c4b15af0a7cc4d13155201e3e09e5a = L.map(
#                 &quot;map_75c4b15af0a7cc4d13155201e3e09e5a&quot;,
#                 {
#                     center: [34.84376653940702, -119.72947980924755],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_75c4b15af0a7cc4d13155201e3e09e5a);
#
#
#
#
#
#             var tile_layer_769eb54c51bbae2c9a3d62be75402cbd = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_769eb54c51bbae2c9a3d62be75402cbd.addTo(map_75c4b15af0a7cc4d13155201e3e09e5a);
#
#
#             var marker_136108f949ecd375c34616c4fbaebd3b = L.marker(
#                 [34.84274931251344, -119.72930436834946],
#                 {
# }
#             ).addTo(map_75c4b15af0a7cc4d13155201e3e09e5a);
#
#
#             var marker_cd14b345af9015d23d2854c3b18f375d = L.marker(
#                 [34.84452978679933, -119.72959195735044],
#                 {
# }
#             ).addTo(map_75c4b15af0a7cc4d13155201e3e09e5a);
#
#
#             var marker_c2911d3a023b2a005261be116912f56a = L.marker(
#                 [34.84194322107738, -119.72912315720413],
#                 {
# }
#             ).addTo(map_75c4b15af0a7cc4d13155201e3e09e5a);
#
#
#             var marker_b7a4580e6a8b90bc206292a00f44942e = L.marker(
#                 [34.84434611854523, -119.72952443022739],
#                 {
# }
#             ).addTo(map_75c4b15af0a7cc4d13155201e3e09e5a);
#
#
#             var marker_f884e10166ff3f30d8aac50f2ac1a73c = L.marker(
#                 [34.845181815938616, -119.7297830160343],
#                 {
# }
#             ).addTo(map_75c4b15af0a7cc4d13155201e3e09e5a);
#
#
#             var marker_62e62cd232cf9877cbf52d2c6ac8b567 = L.marker(
#                 [34.84550303221075, -119.72984958925444],
#                 {
# }
#             ).addTo(map_75c4b15af0a7cc4d13155201e3e09e5a);
#
#
#             var marker_9e4b459d7c13a6b40294d9e84eca8796 = L.marker(
#                 [34.84245630497431, -119.72921456201425],
#                 {
# }
#             ).addTo(map_75c4b15af0a7cc4d13155201e3e09e5a);
#
#
#             var marker_794ac849b57d8f27f67aa4545333b4ed = L.marker(
#                 [34.845022928468225, -119.72978611584432],
#                 {
# }
#             ).addTo(map_75c4b15af0a7cc4d13155201e3e09e5a);
#
#
#             var marker_18eb6fd26a04b17936e44534d389604e = L.marker(
#                 [34.84194084438365, -119.7291634264455],
#                 {
# }
#             ).addTo(map_75c4b15af0a7cc4d13155201e3e09e5a);
#
#
#             var marker_bb4fb99ab1bab64d1167d90c90b79110 = L.marker(
#                 [34.84399202915928, -119.72945746975124],
#                 {
# }
#             ).addTo(map_75c4b15af0a7cc4d13155201e3e09e5a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### peachtree

# %%
df2 = df1.loc[df1['Location'] == 'peachtree']
df2 = df2.iloc[:10, 0:]

# %%
# does not make sense at all, points are in the ocean!!!
center_lat = df2['latitude_grok'].mean()
center_lng = df2['longitude_grok'].mean()
center = [center_lat, center_lng]

m = folium.Map(location=center, control_scale=True, tiles="Cartodb Positron")
for index, row in df2.iterrows():
    folium.Marker(location=[row['latitude_grok'], row['longitude_grok']]).add_to(m)
#m.save('map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5878adaea137c0557d91c3d210958bc4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5878adaea137c0557d91c3d210958bc4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5878adaea137c0557d91c3d210958bc4 = L.map(
#                 &quot;map_5878adaea137c0557d91c3d210958bc4&quot;,
#                 {
#                     center: [31.94581562342147, -131.99169643834236],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_5878adaea137c0557d91c3d210958bc4);
#
#
#
#
#
#             var tile_layer_38f8cab5f9dbd9d512730d3c198f2bd8 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_38f8cab5f9dbd9d512730d3c198f2bd8.addTo(map_5878adaea137c0557d91c3d210958bc4);
#
#
#             var marker_1bea0bcdabc107ff308cb3e9cf6afcb2 = L.marker(
#                 [31.947265662201264, -131.99138776067082],
#                 {
# }
#             ).addTo(map_5878adaea137c0557d91c3d210958bc4);
#
#
#             var marker_9aba739cae257e2b8f52a8a0e6d4c422 = L.marker(
#                 [31.94610492210437, -131.9913189384373],
#                 {
# }
#             ).addTo(map_5878adaea137c0557d91c3d210958bc4);
#
#
#             var marker_1617456986ade32a9d3ef57dfe48b062 = L.marker(
#                 [31.9440952156737, -131.99197659257632],
#                 {
# }
#             ).addTo(map_5878adaea137c0557d91c3d210958bc4);
#
#
#             var marker_a27bcbc80659c595d61b9085cc43c7a9 = L.marker(
#                 [31.9482228876935, -131.99167510815332],
#                 {
# }
#             ).addTo(map_5878adaea137c0557d91c3d210958bc4);
#
#
#             var marker_e29b245b579f074917923068b32b9f66 = L.marker(
#                 [31.948252837114307, -131.99167842623112],
#                 {
# }
#             ).addTo(map_5878adaea137c0557d91c3d210958bc4);
#
#
#             var marker_92c937cd0a2fc7d3451b876f47e5bb0a = L.marker(
#                 [31.943977243459724, -131.99196756129882],
#                 {
# }
#             ).addTo(map_5878adaea137c0557d91c3d210958bc4);
#
#
#             var marker_80bc1ba0d5cf4db0da8be2a67bf563dd = L.marker(
#                 [31.943500225483753, -131.99175807263683],
#                 {
# }
#             ).addTo(map_5878adaea137c0557d91c3d210958bc4);
#
#
#             var marker_e2ab14944aa1a5f56cf4e29b0bca076d = L.marker(
#                 [31.945406295610574, -131.99185792763356],
#                 {
# }
#             ).addTo(map_5878adaea137c0557d91c3d210958bc4);
#
#
#             var marker_3deb826a2ab8cfe86d4024e0735b055b = L.marker(
#                 [31.94634981117412, -131.9913605350633],
#                 {
# }
#             ).addTo(map_5878adaea137c0557d91c3d210958bc4);
#
#
#             var marker_25968f5651c24f36775ed00835675ee5 = L.marker(
#                 [31.944981133699425, -131.99198346072222],
#                 {
# }
#             ).addTo(map_5878adaea137c0557d91c3d210958bc4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### IN THE OCEAN!!! Therefore, need to seriously think about how to convert it properly

# %% [markdown]
# # Two problems:
#
# + These are highways. Not sure if they are suitable for analysis
#
# + The coordinates might not be accurate enough, as cars are in the fields, not on the roads
#
# + Hence, the dataset is not applicable unless we can convert the locations to a good enough precision and prove that this converstion is correct. In that case, the dataset is quite good

# %% [markdown]
# ### PEMS dataset
#
# Obtained from this repository: https://github.com/guoshnBJTU/ASTGNN/tree/main/data
#
# Some notebooks related to the analysis of this dataset:
#
# https://www.kaggle.com/code/jvthunder/pems08-traffic-flow-prediction
#
# https://www.kaggle.com/code/elmahy/astgcn-for-traffic-flow-forecasting
#
# So far found nothing really interesting, hence, use only for supplementary purposes probably

# %%
data = np.load('PEMS03.npz')
data.files
# Out:
# ['data']

# %%
data['data'].shape
# Out:
# (26208, 358, 1)

# %%
data['data']
# Out:
# array([[[ 20.],
#         [ 20.],
#         [182.],
#         ...,
#         [ 63.],
#         [115.],
#         [ 63.]],
#
#        [[ 22.],
#         [ 22.],
#         [174.],
#         ...,
#         [ 63.],
#         [109.],
#         [ 62.]],
#
#        [[ 22.],
#         [ 22.],
#         [183.],
#         ...,
#         [ 57.],
#         [115.],
#         [ 57.]],
#
#        ...,
#
#        [[ 43.],
#         [ 39.],
#         [144.],
#         ...,
#         [124.],
#         [104.],
#         [ 47.]],
#
#        [[ 27.],
#         [ 27.],
#         [115.],
#         ...,
#         [123.],
#         [112.],
#         [ 39.]],
#
#        [[ 48.],
#         [ 52.],
#         [108.],
#         ...,
#         [134.],
#         [115.],
#         [ 38.]]])

# %%
df = pd.read_csv('PEMS03.csv')
df
# Out:
#        from      to  distance
# 0    317842  318711     0.872
# 1    318721  315955     1.322
# 2    315927  318236     1.222
# 3    318711  318721     0.233
# 4    318236  317843     1.220
# ..      ...     ...       ...
# 542  314548  318135     0.586
# 543  314548  318736     0.586
# 544  318126  318052     5.382
# 545  318135  318383     2.183
# 546  318736  318383     2.183
#
# [547 rows x 3 columns]

# %% [markdown]
# ### Don't really know what to do with that, does not seem useful for our purposes

# %% [markdown]
# ### GeoLife GPS Trajectories
#
# Available at https://www.microsoft.com/en-us/download/details.aspx?id=52367
#
# Useful code at https://www.kaggle.com/code/lehongquan/final-datamining-dataset

# %%
def read_plt(plt_file):
    points = pd.read_csv(plt_file, skiprows=6, header=None)

    # for clarity rename columns
    points.rename(inplace=True, columns={0: 'lat', 1: 'lon', 3: 'alt', 5: 'day', 6: 'hour'})
    
    date_format = '%Y-%m-%d %H:%M:%S'
    points['time'] = pd.to_datetime(points['day'] + ' ' + points['hour'], format=date_format)

    # remove unused columns
    points.drop(inplace=True, columns=[2, 4, 'day', 'hour'])

    return points

plt_file = "Geolife Trajectories 1.3/Data/000/Trajectory/20081023025304.plt"
df_plt = read_plt(plt_file)
df_plt
# Out:
#            lat         lon  alt                time
# 0    39.984702  116.318417  492 2008-10-23 02:53:04
# 1    39.984683  116.318450  492 2008-10-23 02:53:10
# 2    39.984686  116.318417  492 2008-10-23 02:53:15
# 3    39.984688  116.318385  492 2008-10-23 02:53:20
# 4    39.984655  116.318263  492 2008-10-23 02:53:25
# ..         ...         ...  ...                 ...
# 903  40.009172  116.321211   88 2008-10-23 11:10:52
# 904  40.009204  116.321130   86 2008-10-23 11:10:57
# 905  40.009243  116.321050   85 2008-10-23 11:11:02
# 906  40.009269  116.320978   84 2008-10-23 11:11:07
# 907  40.009328  116.320887   83 2008-10-23 11:11:12
#
# [908 rows x 4 columns]

# %%
df2 = df_plt.iloc[:50, 0:]

# %%
center_lat = df2['lat'].mean()
center_lng = df2['lon'].mean()
center = [center_lat, center_lng]

m = folium.Map(location=center, control_scale=True, tiles="Cartodb Positron")
for index, row in df2.iterrows():
    folium.Marker(location=[row['lat'], row['lon']]).add_to(m)
#m.save('map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_75a22cdeb5e336a671d471c69b708d4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_75a22cdeb5e336a671d471c69b708d4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_75a22cdeb5e336a671d471c69b708d4f = L.map(
#                 &quot;map_75a22cdeb5e336a671d471c69b708d4f&quot;,
#                 {
#                     center: [39.98460388, 116.31449240000002],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#
#
#
#             var tile_layer_8ecc813cad11977e0d79a1bc0104d505 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ecc813cad11977e0d79a1bc0104d505.addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_fa11309dac8eaefc1c2861324ed4cee2 = L.marker(
#                 [39.984702, 116.318417],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_9f0db8cde2be44ac6027b19f7192c2fb = L.marker(
#                 [39.984683, 116.31845],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_5622812f1693c794005b57e53cf72d00 = L.marker(
#                 [39.984686, 116.318417],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_4adead92f383b49d37f2d1686d88c0cc = L.marker(
#                 [39.984688, 116.318385],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_291e5aa76f958b61ad89b60fd7a939f5 = L.marker(
#                 [39.984655, 116.318263],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_6b552252024e4643e2359d278986997a = L.marker(
#                 [39.984611, 116.318026],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_5030c00e9ea1d0d48e8b69c8df9c6fe5 = L.marker(
#                 [39.984608, 116.317761],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_0574de7ddafdb9cdffb3637bdf8afeb6 = L.marker(
#                 [39.984563, 116.317517],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_f3e828934a210054fec0e4defeb5ff0e = L.marker(
#                 [39.984539, 116.317294],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_dd4d3e9619610b9df7c644573047a38f = L.marker(
#                 [39.984606, 116.317065],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_1e8d484e3559f11fd760d613a8269ddc = L.marker(
#                 [39.984568, 116.316911],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_6095b66886ea4d69cd2633564bf3e177 = L.marker(
#                 [39.984586, 116.316716],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_637ef5d6e3859ae55b3933527b266804 = L.marker(
#                 [39.984561, 116.316527],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_7d53bbbf2992e405af1d7f90faa06f95 = L.marker(
#                 [39.984536, 116.316354],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_4b49362f581564ad41ccda1fac7fbe1c = L.marker(
#                 [39.984523, 116.316188],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_08ba95cad3a8f4f63ae29c737a28dbb6 = L.marker(
#                 [39.984516, 116.315963],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_a2a46d2d0e0c5582324ba3cfc4bf633f = L.marker(
#                 [39.984523, 116.315823],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_5f3300461a8a2990cb61ebcf903200a5 = L.marker(
#                 [39.984574, 116.315611],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_f9ba38133200d961e4652084b78e5e49 = L.marker(
#                 [39.984568, 116.315407],
#                 {
# }
#             ).addTo(map_75a22cdeb5e336a671d471c69b708d4f);
#
#
#             var marker_853c82653b58f642e5dd5cb0eccdbe22 = L.marker(

# %% [markdown]
# # I think this is by far the best dataset:
#
# + Coordinates in lat, lon
#
# + Seems like everything is updates every five seconds, hence, can built the routes and estimate the heaviness of the traffic
#
# + Although the data is old, the dataset was published in 2024, and by Microsoft (hence, should be realiable and make sense)
#
# + It is mainly Beijing, hence, makes sense to analyze the disctict we are currently at

# %% [markdown]
# ### Other possible datasets (still need to check them):
#
# https://utd19.ethz.ch/ - requested data
#
# https://datarade.ai/data-categories/car-traffic-data
